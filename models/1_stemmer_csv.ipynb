# %% [markdown]
# # Alterar CSV

# %% [markdown]
# - Versão feita em **21 março de 2024** para rodar no Colab

# %% [markdown]
# **Missão:** Este arquivo tem por objetivo realizar a **Stemmatização** no **dataset_pre_processado_2.csv.**

# %% [markdown]
# ## Dataset com pré-processamento: *dataset_pre_processado_2.csv*

# %%
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
import numpy as np

# %%
# Pré-processamento
nltk.download('punkt')
nltk.download('rslp')
stemmer = RSLPStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %%
df = pd.read_csv("dataset_pre_processado_2.csv")
df.head(2)
# Out:
#    id                                             titulo  \
# 0  61  guerra eletrônica e defesa cibernética na amaz...
# 1  31  centro de avaliações do exército finaliza test...
#
#                                                autor  \
# 0  cristiano torres do amaral, edilson vasconcelo...
# 1                             Noticiário do Exército
#
#                                                  url      tipo_documento  \
# 0  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 1  https://www.eb.mil.br/web/noticias/noticiario-...             Notícia
#
#    rotulo                                             resumo  \
# 0       2  regiao amazonica possui extensa area fronteira...
# 1       3  rio janeiro rj centro avaliacoes exercito caex...
#
#                                                texto
# 0  expansao grupos ligados faccoes criminosas mil...
# 1  rio janeiro rj centro avaliacoes exercito caex...

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)  # Tokenização e conversão para minúsculas
    tokens = [stemmer.stem(token) for token in tokens]  # Stemmatização
    return ' '.join(tokens)

# %%
df['resumo'] = df['resumo'].apply(preprocess_text)

# %%
df['texto'] = df['texto'].apply(preprocess_text)

# %%
df
# Out:
#       id                                             titulo  \
# 0     61  guerra eletrônica e defesa cibernética na amaz...
# 1     31  centro de avaliações do exército finaliza test...
# 2     71  excitação e transmissão de ondas eletromagnéti...
# 3    110   caracterização do óculos de visão noturna em ...
# 4    170  aplicação de titanato zirconato de chumbo no d...
# ..   ...                                                ...
# 163  111  geração de sinais por técnicas fotônicas de co...
# 164   62  proposta de um receptor de guerra eletrônica m...
# 165   59  knn e rede neural convolucional para o reconhe...
# 166  137  redução de dimensionalidade por transformação ...
# 167   76  a interoperabilidade nas comunicações de dados...
#
#                                                  autor  \
# 0    cristiano torres do amaral, edilson vasconcelo...
# 1                               Noticiário do Exército
# 2       Joaquim Paulino Leite Neto, Joaquim J. Barroso
# 3    cristiano link, ernesto cordeiro marujo e deni...
# 4    silva neto, l. p., silva junior, a. r., rossi,...
# ..                                                 ...
# 163  romildo henrique de souza, olympio. l. coutinh...
# 164  André Paim Gonçalves, Renan Miranda Richter, F...
# 165  Leonan Entringer Falqueto, Ricardo Suterio, Ra...
# 166  carlos cypriano vallim junior, felipe aurélio ...
# 167        márcio gonçalves ramos, pablo pontes arraes
#
#                                                    url      tipo_documento  \
# 0    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 1    https://www.eb.mil.br/web/noticias/noticiario-...             Notícia
# 2    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 3    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 4    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# ..                                                 ...                 ...
# 163  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 164  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 165  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 166  http://www.ebrevistas.eb.mil.br/CT/article/vie...   Artigo de Revista
# 167  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
#
#      rotulo                                             resumo  \
# 0         2  regia amazon possu extens are fronteir biodive...
# 1         3  rio jan rj centr avaliaco exercit caex camp pr...
# 2         1  metod excitaca gui ond evanesc carreg metamate...
# 3         3  trabalh descrev test realiz caracterizaca equi...
# 4         1  capaci ceram comerc bas titanat bari dop estro...
# ..      ...                                                ...
# 163       2  promis are rf foton possibilit atend demand la...
# 164       1  artig apresent propost recep guerr eletron mic...
# 165       2  reconhec automa alv plataform petrolif mei ima...
# 166       1  princip aplicaco process adapt espacotemp spac...
# 167       3  modern sistem milit transmissa dad espectr rad...
#
#                                                  texto
# 0    expansa grup lig facco crimin milic avanc dife...
# 1    rio jan rj centr avaliaco exercit caex camp pr...
# 2    gui ond retangul sid ampl us estrut basic gui ...
# 3    inici aviaca brasil ativ busc salv sar lev efe...
# 4    ceram dieletr sid utiliz mei dieletr disposi a...
# ..                                                 ...
# 163  advent comunicaco digit introduz tecn modulaca...
# 164  advent empreg satelit aeronav remot pilot guer...
# 165  brasil assim demal pais grand dimenso territor...
# 166  process espacotemp usual refer process adapt e...
# 167  brasil pal dimenso continent exig avanc equip ...
#
# [168 rows x 8 columns]

# %%
# Exportando o DataFrame para um arquivo CSV
df.to_csv('dataset_pre_processado_stem_2.csv', index=False)
