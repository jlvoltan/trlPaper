# %% [markdown]
# # Alterar CSV

# %% [markdown]
# - Versão feita em **18 outubro de 2023** para rodar no Colab

# %% [markdown]
# **Missão:** Este arquivo tem por objetivo realizar a **Stemmatização** no **dataset_pre_processado_2.csv.**

# %% [markdown]
# ## Dataset com pré-processamento: *dataset_pre_processado_2.csv*

# %%
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd
import numpy as np

# %%
# Pré-processamento
nltk.download('punkt')
nltk.download('rslp')
stemmer = RSLPStemmer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package rslp to /root/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.

# %%
df = pd.read_csv("dataset_pre_processado_2.csv")
df.head(2)
# Out:
#     id                                             titulo  \
# 0   88  estudo dos efeitos de dircm em mísseis infrave...
# 1  125  caracterização de capacitores cerâmicos na fai...
#
#                                                autor  \
# 0  caio augusto de melo silvestre, lester de abre...
# 1     silva neto, l. p., rossi, j. o., barroso j. j.
#
#                                                  url      tipo_documento  \
# 0  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 1  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
#
#    rotulo                                             resumo  \
# 0       1  crescente emprego misseis ombro infravermelhos...
# 1       2  materiais dieletricos baixas perdas alta permi...
#
#                                                texto
# 0  misseis infravermelhos especialmente tipo manp...
# 1  introducao ceramicas dieletricas encontram imp...

# %%
def preprocess_text(text):
    tokens = word_tokenize(text)  # Tokenização e conversão para minúsculas
    tokens = [stemmer.stem(token) for token in tokens]  # Stemmatização
    return ' '.join(tokens)

# %%
df['resumo'] = df['resumo'].apply(preprocess_text)

# %%
df
# Out:
#       id                                             titulo  \
# 0     88  estudo dos efeitos de dircm em mísseis infrave...
# 1    125  caracterização de capacitores cerâmicos na fai...
# 2     35  avaliação de algoritmos de machine learning na...
# 3    147  avaliação de desempenho de redes tolerantes a ...
# 4    104   uma arquitetura para radar secundário nos mod...
# ..   ...                                                ...
# 163   33  centro de avaliações do exército conclui teste...
# 164  139  sarp aplicado ao monitoramento de áreas com di...
# 165   66  planejador de missões do rádio definido por so...
# 166  165  verificação de velocidade de alvos marítimos m...
# 167  169  emprego de métodos de onda completa para análi...
#
#                                                  autor  \
# 0    caio augusto de melo silvestre, lester de abre...
# 1       silva neto, l. p., rossi, j. o., barroso j. j.
# 2    fabiano g. da silva, lucas p. ramos, bruna g. ...
# 3    davi marinho de a falcão, ronaldo moreira sall...
# 4                    vitor augusto ferreira santa rita
# ..                                                 ...
# 163                             Noticiário do Exército
# 164  luis claudio batista da silva, ricardo maroqui...
# 165  Victor Feitosa de Carvalho Souza, Fillipe Mach...
# 166  marcos roberto seixas, rafael lemos paes e dav...
# 167  rodrigo rodrigues de assis, leandro napoli bel...
#
#                                                    url      tipo_documento  \
# 0    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 1    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 2    https://www.sige.ita.br/edicoes-anteriores/202...  Artigo de Simpósio
# 3    http://www.ebrevistas.eb.mil.br/CT/article/vie...   Artigo de Revista
# 4    https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# ..                                                 ...                 ...
# 163  https://www.eb.mil.br/web/noticias/noticiario-...             Notícia
# 164  http://www.ebrevistas.eb.mil.br/CT/article/vie...   Artigo de Revista
# 165  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 166  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
# 167  https://www.sige.ita.br/edicoes-anteriores/201...  Artigo de Simpósio
#
#      rotulo                                             resumo  \
# 0         1  cresc empreg missel ombr infravermelh contr al...
# 1         2  mater dieletr baix perd alt permiss compon ess...
# 2         1  recent disponibil dad publ sensor remot obt at...
# 3         1  disruptiontolerant network dtn evoluca mobil a...
# 4         2  nest artig apresent arquitet rad secundari ope...
# ..      ...                                                ...
# 163       3  rio jan rj centr avaliaco exercit caex camp pr...
# 164       3  trabalh apresent sistem control multipl aerona...
# 165       3  context comunicaco tatic base uso radi defin s...
# 166       1  val veloc alv movel imag obt rad abert sinte s...
# 167       1  nest artig apresent analis seca ret rad rc rad...
#
#                                                  texto
# 0    misseis infravermelhos especialmente tipo manp...
# 1    introducao ceramicas dieletricas encontram imp...
# 2    introducao imagens orbitais sido utilizadas se...
# 3    introducao otransporte maritimo responsavel co...
# 4    introducao modos operacao c radares secundario...
# ..                                                 ...
# 163  rio janeiro rj centro avaliacoes exercito caex...
# 164  introducao sistemas aeronaves remotamente pilo...
# 165  introducao conceito radio definido software rd...
# 166  introducao sistema sar utilizado meio militar ...
# 167  introducao sobrevivencia aeronave combate vigi...
#
# [168 rows x 8 columns]

# %%
# Exportando o DataFrame para um arquivo CSV
df.to_csv('dataset_pre_processado_stem_2.csv', index=False)
